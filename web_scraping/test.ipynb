# %%
import pandas as pd

data = pd.read_json("player_details.json")
df = pd.DataFrame(data)
df
# Out:
#       Player_ID             Name Date of birth Place of birth   Age  Height  \
# 0        427605  Aaron Boupendza   Aug 7, 1996         Moanda  26.0  1,80 m
# 1        434207   Aaron Connolly  Jan 28, 2000         Galway  23.0  1,74 m
# 2         92571  Aaron Cresswell  Dec 15, 1989      Liverpool  33.0  1,70 m
# 3        284430  Aarón Escandell  Sep 27, 1995     Carcaixent  27.0  1,85 m
# 4        276566     Aaron Herzog  Jan 30, 1998           Köln  25.0  1,80 m
# ...         ...              ...           ...            ...   ...     ...
# 9360      61591    Zoltn Stieber  Oct 16, 1988           Srvr  34.0  1,75 m
# 9361     129386   Zouhair Feddal  Dec 23, 1989         Ttouan  33.0  1,91 m
# 9362     563335   Zourdine Thior   Jul 9, 1997          Dakar  25.0  1,70 m
# 9363     199268      Zsolt Kalmr   Jun 9, 1995           Győr  27.0  1,85 m
# 9364     663519    Zsombor Senkó   Jan 4, 2003   Zalaegerszeg  20.0  1,96 m
#
# ...
